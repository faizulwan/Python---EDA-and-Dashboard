# %%
## Basic Package

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
## Handling Outliers
Opsi handling outliers ==> Drop atau Keep

Penyebab
1. Kesalahan Input : 2500 ==> Typo seharusnya 25 ==> Drop
2. Outliers yang datanya kita pakai
3. Data benar ==> Harga Mobil (Kijang GLX, APV, Xenia, Avanza, Ferrari, Lamborghini) ==> Drop Ferrari dan Lamborghini (untuk menganalisa mobil rakyat)
 dan sebaliknya. Ketika ingin dianalisa dua2nya maka buat DataFrame yang berbeda
    1. df_rakjat = df[df['harga']< 1M]
    2. df_rakjat = df[df['harga']> 1M]
# Out:
#   File "<ipython-input-3-e0f649c0771c>", line 2
#     Opsi handling outliers ==> Drop atau Keep
#          ^
# SyntaxError: invalid syntax

# %%
## Handling Missing Value
Opsi handling missing Value ==> Drop atau Fill (Data sintetis)

 1. Drop ==> Kolom atau Baris
    Drop Kolom:
     - Terdapat kolom pengganti : Misal missing value ada di kolom jarak (m), Kita memiliki kolom jarak (km)
                                  Missing value di Gaji (Rp), kiota memiliki Gaji (USD)
                
     - 70 - 80% Missing valuenya

   Drop Baris:
     - Lihat berapa banyak Kolom yang kosong di baris tersebut
     - Pastikan jumlah datanya banyak
         Misal kita ingin prediksi : Macet : Ngga
                Macet = 990
                Ngga = 10

Features & Targer ==> Machine Learning

Jika ada missing value pada kolom Target ==> Langsung Drop Baris


 2. FillNa ==> Mengisi Data Sintetis
    - Harus melihat kolom / features lain
    - Mean ==> Data numerik dan tidak ada outliers
    - Median ==> Data numerik 
    - Modul ==> Data kategorikal
    df[(df['jabatan']== 'manajer') & (df['lokasi'] == 'solo')].mean()

# %%
df = pd.read_csv('data.csv')
df
# Out:
#        receipt_id  receipts_item_id     purchase_time              category  \
# 0         9622257          32369294   7/22/2018 21:19                  Rice
# 1         9446359          31885876   7/15/2018 16:17                  Rice
# 2         9470290          31930241   7/15/2018 12:12                  Rice
# 3         9643416          32418582    7/24/2018 8:27                  Rice
# 4         9692093          32561236   7/26/2018 11:28                  Rice
# ...           ...               ...               ...                   ...
# 71995     5909305          17998610   12/27/2017 9:20  Sugar/Flavored Syrup
# 71996     5736299          17432379  12/13/2017 19:52  Sugar/Flavored Syrup
# 71997     5901144          18263665   12/27/2017 8:03  Sugar/Flavored Syrup
# 71998     5660630          17222218  12/07/2017 12:29  Sugar/Flavored Syrup
# 71999     5808147          17658789  12/19/2017 18:59  Sugar/Flavored Syrup
#
# ...

# %%
df.sample(5)
# Out:
#        receipt_id  receipts_item_id     purchase_time              category  \
# 59271     7052680          21127343   3/13/2018 13:21  Sugar/Flavored Syrup
# 12124     9706137          32591257   7/26/2018 20:34           Fabric Care
# 69987     5291944          16035727  11/03/2017 12:00  Sugar/Flavored Syrup
# 10420     5529743          16783552  11/26/2017 18:31                  Rice
# 5383      7374904          22053674   3/28/2018 20:01                  Rice
#
#       sub_category      format  unit_price  discount  quantity
# 59271        Sugar  minimarket     13500.0         0         1
# 12124    Detergent  minimarket     10000.0      6800         1
# 69987        Sugar  minimarket     13500.0         0         1
# 10420         Rice  minimarket     62500.0         0         1
# 5383          Rice  minimarket     63300.0         0         2

# %%
### Alternatif 1
df.set_index('receipt_id')
# Out:
#             receipts_item_id     purchase_time              category  \
# receipt_id
# 9622257             32369294   7/22/2018 21:19                  Rice
# 9446359             31885876   7/15/2018 16:17                  Rice
# 9470290             31930241   7/15/2018 12:12                  Rice
# 9643416             32418582    7/24/2018 8:27                  Rice
# 9692093             32561236   7/26/2018 11:28                  Rice
# ...                      ...               ...                   ...
# 5909305             17998610   12/27/2017 9:20  Sugar/Flavored Syrup
# 5736299             17432379  12/13/2017 19:52  Sugar/Flavored Syrup
# 5901144             18263665   12/27/2017 8:03  Sugar/Flavored Syrup
# 5660630             17222218  12/07/2017 12:29  Sugar/Flavored Syrup
# 5808147             17658789  12/19/2017 18:59  Sugar/Flavored Syrup
#
#            sub_category       format  unit_price  discount  quantity
# receipt_id
# ...

# %%
### Alternatif 2
df = pd.read_csv('data.csv', index_col='receipt_id')
df.head()
# Out:
#             receipts_item_id    purchase_time category sub_category  \
# receipt_id
# 9622257             32369294  7/22/2018 21:19     Rice         Rice
# 9446359             31885876  7/15/2018 16:17     Rice         Rice
# 9470290             31930241  7/15/2018 12:12     Rice         Rice
# 9643416             32418582   7/24/2018 8:27     Rice         Rice
# 9692093             32561236  7/26/2018 11:28     Rice         Rice
#
#                  format  unit_price  discount  quantity
# receipt_id
# 9622257     supermarket    128000.0         0         1
# 9446359      minimarket    102750.0         0         1
# 9470290     supermarket     64000.0         0         3
# 9643416      minimarket     65000.0         0         1
# 9692093     supermarket    124500.0         0         1

# %%
### Alternatif 3
df = pd.read_csv('data.csv', index_col=0)
df.head()
# Out:
#             receipts_item_id    purchase_time category sub_category  \
# receipt_id
# 9622257             32369294  7/22/2018 21:19     Rice         Rice
# 9446359             31885876  7/15/2018 16:17     Rice         Rice
# 9470290             31930241  7/15/2018 12:12     Rice         Rice
# 9643416             32418582   7/24/2018 8:27     Rice         Rice
# 9692093             32561236  7/26/2018 11:28     Rice         Rice
#
#                  format  unit_price  discount  quantity
# receipt_id
# 9622257     supermarket    128000.0         0         1
# 9446359      minimarket    102750.0         0         1
# 9470290     supermarket     64000.0         0         3
# 9643416      minimarket     65000.0         0         1
# 9692093     supermarket    124500.0         0         1

# %%
## Pengecekan tipe data
### ALt 1
df.dtypes
# Out:
# receipts_item_id      int64
# purchase_time        object
# category             object
# sub_category         object
# format               object
# unit_price          float64
# discount              int64
# quantity              int64
# dtype: object

# %%
## Alt 2
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72000 entries, 9622257 to 5808147
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   receipts_item_id  72000 non-null  int64
#  1   purchase_time     72000 non-null  object
#  2   category          72000 non-null  object
#  3   sub_category      72000 non-null  object
#  4   format            72000 non-null  object
#  5   unit_price        72000 non-null  float64
#  6   discount          72000 non-null  int64
#  7   quantity          72000 non-null  int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 4.9+ MB

# %%
### Check Missing value
# Alt 1
df.isnull().sum()
# Out:
# receipts_item_id    0
# purchase_time       0
# category            0
# sub_category        0
# format              0
# unit_price          0
# discount            0
# quantity            0
# dtype: int64

# %%
# Alt 2
df.isna().sum()
# Out:
# receipts_item_id    0
# purchase_time       0
# category            0
# sub_category        0
# format              0
# unit_price          0
# discount            0
# quantity            0
# dtype: int64

# %%
### Decribe Data Numerik
# Descriptive statistic untuk tipe data numeric
df.describe()
# Out:
#        receipts_item_id     unit_price       discount      quantity
# count      7.200000e+04   72000.000000   72000.000000  72000.000000
# mean       2.459002e+07   24830.776334     852.195139      1.482861
# std        7.169571e+06   24496.419282    4051.061578      1.289382
# min        8.904708e+06    2505.000000  -49600.000000      1.000000
# 25%        1.819982e+07   12500.000000       0.000000      1.000000
# 50%        2.236586e+07   15472.500000       0.000000      1.000000
# 75%        3.105228e+07   25100.000000       0.000000      2.000000
# max        3.850166e+07  219400.000000  320000.000000     19.000000

# %%
### Decribe Data object
# Alt 1
df.describe(include = np.object)
# Out:
#            purchase_time     category sub_category      format
# count              72000        72000        72000       72000
# unique             62072            3            3           3
# top     10/22/2017 12:00  Fabric Care    Detergent  minimarket
# freq                  12        36000        36000       46803

# %%
# Alt 2
df.describe(include = 'O')
# Out:
#            purchase_time     category sub_category      format
# count              72000        72000        72000       72000
# unique             62072            3            3           3
# top     10/22/2017 12:00  Fabric Care    Detergent  minimarket
# freq                  12        36000        36000       46803

# %%
# Alt 3
df.describe(include = ['object'])
# Out:
#            purchase_time     category sub_category      format
# count              72000        72000        72000       72000
# unique             62072            3            3           3
# top     10/22/2017 12:00  Fabric Care    Detergent  minimarket
# freq                  12        36000        36000       46803

# %%
count = jumlah data
unique = jumlah unique data
top = data yang paling sering muncul
freq = Jumlah berapa kali modus muncul
# Out:
#   File "<ipython-input-31-d969c5c0de06>", line 1
#     count = jumlah data
#                    ^
# SyntaxError: invalid syntax

# %%
# Alt 4
df.describe(include = 'all')
# Out:
#         receipts_item_id     purchase_time     category sub_category  \
# count       7.200000e+04             72000        72000        72000
# unique               NaN             62072            3            3
# top                  NaN  10/22/2017 12:00  Fabric Care    Detergent
# freq                 NaN                12        36000        36000
# mean        2.459002e+07               NaN          NaN          NaN
# std         7.169571e+06               NaN          NaN          NaN
# min         8.904708e+06               NaN          NaN          NaN
# 25%         1.819982e+07               NaN          NaN          NaN
# 50%         2.236586e+07               NaN          NaN          NaN
# 75%         3.105228e+07               NaN          NaN          NaN
# max         3.850166e+07               NaN          NaN          NaN
#
#             format     unit_price       discount      quantity
# count        72000   72000.000000   72000.000000  72000.000000
# ...

# %%
## Pengecekkan Outliers
Outliers adalah data yang diatas Upper fence atau diatas lower fence
# Out:
#   File "<ipython-input-33-dac5686efc72>", line 2
#     Outliers adalah data yang diatas Upper fence atau diatas lower fence
#              ^
# SyntaxError: invalid syntax

# %%
df.describe().T
# Out:
#                     count          mean           std        min          25%  \
# receipts_item_id  72000.0  2.459002e+07  7.169571e+06  8904708.0  18199818.75
# unit_price        72000.0  2.483078e+04  2.449642e+04     2505.0     12500.00
# discount          72000.0  8.521951e+02  4.051062e+03   -49600.0         0.00
# quantity          72000.0  1.482861e+00  1.289382e+00        1.0         1.00
#
#                          50%          75%         max
# receipts_item_id  22365857.0  31052282.25  38501658.0
# unit_price           15472.5     25100.00    219400.0
# discount                 0.0         0.00    320000.0
# quantity                 1.0         2.00        19.0

# %%
## Mencari outliers untuk unit price
df.describe()['unit_price']
# Out:
# count     72000.000000
# mean      24830.776334
# std       24496.419282
# min        2505.000000
# 25%       12500.000000
# 50%       15472.500000
# 75%       25100.000000
# max      219400.000000
# Name: unit_price, dtype: float64

# %%
Q1 = df.describe()['unit_price']['25%']

# %%
Q3 = df.describe()['unit_price']['75%']

# %%
IQR = Q3 - Q1

# %%
Upper_Fence = Q3 + (1.5 * IQR)
Lower_Fence = Q1 - (1.5 * IQR)

# %%
## Data Outliers
df[(df['unit_price'] < Lower_Fence) | (df['unit_price'] > Upper_Fence)]
# Out:
#             receipts_item_id     purchase_time              category  \
# receipt_id
# 9622257             32369294   7/22/2018 21:19                  Rice
# 9446359             31885876   7/15/2018 16:17                  Rice
# 9470290             31930241   7/15/2018 12:12                  Rice
# 9643416             32418582    7/24/2018 8:27                  Rice
# 9692093             32561236   7/26/2018 11:28                  Rice
# ...                      ...               ...                   ...
# 5965798             18136614  12/31/2017 17:50  Sugar/Flavored Syrup
# 5742503             17449270  12/12/2017 15:57  Sugar/Flavored Syrup
# 5648387             17146348  12/06/2017 14:14  Sugar/Flavored Syrup
# 5763026             17508220  12/14/2017 17:29  Sugar/Flavored Syrup
# 5906213             17966261  12/26/2017 17:05  Sugar/Flavored Syrup
#
#            sub_category       format  unit_price  discount  quantity
# receipt_id
# ...

# %%
df.head()
# Out:
#             receipts_item_id    purchase_time category sub_category  \
# receipt_id
# 9622257             32369294  7/22/2018 21:19     Rice         Rice
# 9446359             31885876  7/15/2018 16:17     Rice         Rice
# 9470290             31930241  7/15/2018 12:12     Rice         Rice
# 9643416             32418582   7/24/2018 8:27     Rice         Rice
# 9692093             32561236  7/26/2018 11:28     Rice         Rice
#
#                  format  unit_price  discount  quantity
# receipt_id
# 9622257     supermarket    128000.0         0         1
# 9446359      minimarket    102750.0         0         1
# 9470290     supermarket     64000.0         0         3
# 9643416      minimarket     65000.0         0         1
# 9692093     supermarket    124500.0         0         1

# %%
df['category'].unique()
# Out:
# array(['Rice', 'Fabric Care', 'Sugar/Flavored Syrup'], dtype=object)

# %%
df['category'].nunique()
# Out:
# 3

# %%
df['category'].dtypes
# Out:
# dtype('O')

# %%
df['category'].isna().sum()
# Out:
# 0

# %%
round(((df['category'].isna().sum() / (len(df))) ** 100), 2)                # Persentase
# Out:
# 0.0

# %%
df['category'].drop_duplicates().sample(2).values
# Out:
# array(['Rice', 'Fabric Care'], dtype=object)

# %%
df.columns
# Out:
# Index(['receipts_item_id', 'purchase_time', 'category', 'sub_category',
#        'format', 'unit_price', 'discount', 'quantity'],
#       dtype='object')

# %%
dataDesc = []

for i in df.columns:
    dataDesc.append([
        i,
        df[i].dtypes,
        df[i].isna().sum(),
        round(((df[i].isna().sum() / (len(df))) ** 100), 2),
        df[i].nunique(),
        df[i].drop_duplicates().sample(2).values
    ])

# %%
pd.DataFrame(dataDesc, columns=[
    'Data Features',
    'Data Types',
    'Null',
    'Null Percentage',
    'Unique',
    'Unique Sample'
])
# Out:
#       Data Features Data Types  Null  Null Percentage  Unique  \
# 0  receipts_item_id      int64     0              0.0   72000
# 1     purchase_time     object     0              0.0   62072
# 2          category     object     0              0.0       3
# 3      sub_category     object     0              0.0       3
# 4            format     object     0              0.0       3
# 5        unit_price    float64     0              0.0    3884
# 6          discount      int64     0              0.0    1329
# 7          quantity      int64     0              0.0      19
#
#                          Unique Sample
# 0                 [24721861, 23562003]
# 1  [4/19/2018 10:31, 07/07/2018 09:35]
# 2                  [Fabric Care, Rice]
# 3                        [Sugar, Rice]
# 4           [supermarket, hypermarket]
# 5                   [115400.0, 2921.0]
# 6                         [2430, 4820]
# 7                              [12, 5]

# %%
## Jika kolom tanggal bertipe Object maka ==> Harus dikonversi menjadi DateTime

# %%
# Alt 1
# Menggunakan parse_dates = [nama kolom] ketika di awal membaca file

# %%
df = pd.read_csv('data.csv', index_col = 0, parse_dates=['purchase_time'])
df.head()
# Out:
#             receipts_item_id       purchase_time category sub_category  \
# receipt_id
# 9622257             32369294 2018-07-22 21:19:00     Rice         Rice
# 9446359             31885876 2018-07-15 16:17:00     Rice         Rice
# 9470290             31930241 2018-07-15 12:12:00     Rice         Rice
# 9643416             32418582 2018-07-24 08:27:00     Rice         Rice
# 9692093             32561236 2018-07-26 11:28:00     Rice         Rice
#
#                  format  unit_price  discount  quantity
# receipt_id
# 9622257     supermarket    128000.0         0         1
# 9446359      minimarket    102750.0         0         1
# 9470290     supermarket     64000.0         0         3
# 9643416      minimarket     65000.0         0         1
# 9692093     supermarket    124500.0         0         1

# %%
df.dtypes
# Out:
# receipts_item_id             int64
# purchase_time       datetime64[ns]
# category                    object
# sub_category                object
# format                      object
# unit_price                 float64
# discount                     int64
# quantity                     int64
# dtype: object

# %%
# Alt 2
# Menggunakan fungsi .astype('datetime64')
3 astype digunakan untuk mengubah semu tipe data
# Out:
#   File "<ipython-input-55-8e79364122d6>", line 3
#     3 astype digunakan untuk mengubah semu tipe data
#       ^
# SyntaxError: invalid syntax

# %%
df['purchase_time'] = df['purchase_time'].astype('datetime64')

# %%
df.types
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-3c024b1b554d> in <module>
# ----> 1 df.types
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'types'

# %%
#Alt 3
# Menggunakan to_datetime('nama kolom')

# %%
df['purchase_time'] = pd.to_datetime(df['purchase_time'])

# %%
df.dtypes

# %%
tanggal = pd.Series(['31-03-2020', '01-04-2020', '02-04-2020', '03-04-2020', '04-04-2020'])
tanggal
# Out:
# 0    31-03-2020
# 1    01-04-2020
# 2    02-04-2020
# 3    03-04-2020
# 4    04-04-2020
# dtype: object

# %%
tanggal.astype('datetime64')
# Out:
# 0   2020-03-31
# 1   2020-01-04
# 2   2020-02-04
# 3   2020-03-04
# 4   2020-04-04
# dtype: datetime64[ns]

# %%
pd.to_datetime(tanggal)
# Out:
# 0   2020-03-31
# 1   2020-01-04
# 2   2020-02-04
# 3   2020-03-04
# 4   2020-04-04
# dtype: datetime64[ns]

# %%
pd.to_datetime(tanggal, dayfirst=True)
# Out:
# 0   2020-03-31
# 1   2020-04-01
# 2   2020-04-02
# 3   2020-04-03
# 4   2020-04-04
# dtype: datetime64[ns]

# %%
#strftime.org
pd.to_datetime(tanggal, format='%d-%m-%Y')
# Out:
# 0   2020-03-31
# 1   2020-04-01
# 2   2020-04-02
# 3   2020-04-03
# 4   2020-04-04
# dtype: datetime64[ns]

# %%
tgl = pd.Series([
        '01-maret-2020',
        'july/17/2019',
        'Agustus-20-2021',
        '16-August-2020',
        '20/may/2017',
        '2021/01/29'
])
tgl

## Data/format tanggal tersebut butuh package dateparser
# Out:
# 0      01-maret-2020
# 1       july/17/2019
# 2    Agustus-20-2021
# 3     16-August-2020
# 4        20/may/2017
# 5         2021/01/29
# dtype: object

# %%
# !pip install dateparser

# %%
import dateparser

# %%
tgl
# Out:
# 0      01-maret-2020
# 1       july/17/2019
# 2    Agustus-20-2021
# 3     16-August-2020
# 4        20/may/2017
# 5         2021/01/29
# dtype: object

# %%
tgl.apply(dateparser.parse)
# Out:
# 0   2020-03-01
# 1   2019-07-17
# 2   2021-08-20
# 3   2020-08-16
# 4   2017-05-20
# 5   2021-01-29
# dtype: datetime64[ns]

# %%
purchase_dt = df['purchase_time'].apply(dateparser.parse)

# %%
## Proses Ektraksi Tanggal
purchase_dt = df['purchase_time'].dt

# %%
## Ambil Data Bulan, berupa angka
purchase_dt.month.head()
# Out:
# receipt_id
# 9622257    7
# 9446359    7
# 9470290    7
# 9643416    7
# 9692093    7
# Name: purchase_time, dtype: int64

# %%
## Ambil Data Bulan, berupa angka
purchase_dt.month_name().head()
# Out:
# receipt_id
# 9622257    July
# 9446359    July
# 9470290    July
# 9643416    July
# 9692093    July
# Name: purchase_time, dtype: object

# %%
purchase_dt.year.head()
# Out:
# receipt_id
# 9622257    2018
# 9446359    2018
# 9470290    2018
# 9643416    2018
# 9692093    2018
# Name: purchase_time, dtype: int64

# %%
df['month'] = purchase_dt.month_name()

# %%
df.head()
# Out:
#             receipts_item_id       purchase_time category sub_category  \
# receipt_id
# 9622257             32369294 2018-07-22 21:19:00     Rice         Rice
# 9446359             31885876 2018-07-15 16:17:00     Rice         Rice
# 9470290             31930241 2018-07-15 12:12:00     Rice         Rice
# 9643416             32418582 2018-07-24 08:27:00     Rice         Rice
# 9692093             32561236 2018-07-26 11:28:00     Rice         Rice
#
#                  format  unit_price  discount  quantity month
# receipt_id
# 9622257     supermarket    128000.0         0         1  July
# 9446359      minimarket    102750.0         0         1  July
# 9470290     supermarket     64000.0         0         3  July
# 9643416      minimarket     65000.0         0         1  July
# 9692093     supermarket    124500.0         0         1  July

# %%
df['year'] = purchase_dt.year  ## Ekstraksi tahub

# %%
df.head()
# Out:
#             receipts_item_id       purchase_time category sub_category  \
# receipt_id
# 9622257             32369294 2018-07-22 21:19:00     Rice         Rice
# 9446359             31885876 2018-07-15 16:17:00     Rice         Rice
# 9470290             31930241 2018-07-15 12:12:00     Rice         Rice
# 9643416             32418582 2018-07-24 08:27:00     Rice         Rice
# 9692093             32561236 2018-07-26 11:28:00     Rice         Rice
#
#                  format  unit_price  discount  quantity month  year
# receipt_id
# 9622257     supermarket    128000.0         0         1  July  2018
# 9446359      minimarket    102750.0         0         1  July  2018
# 9470290     supermarket     64000.0         0         3  July  2018
# 9643416      minimarket     65000.0         0         1  July  2018
# 9692093     supermarket    124500.0         0         1  July  2018

# %%
df.drop('yaer', axis = 1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-84-f0d0a9613010> in <module>
# ----> 1 df.drop('yaer', axis = 1, inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
df
# Out:
#             receipts_item_id       purchase_time              category  \
# receipt_id
# 9622257             32369294 2018-07-22 21:19:00                  Rice
# 9446359             31885876 2018-07-15 16:17:00                  Rice
# 9470290             31930241 2018-07-15 12:12:00                  Rice
# 9643416             32418582 2018-07-24 08:27:00                  Rice
# 9692093             32561236 2018-07-26 11:28:00                  Rice
# ...                      ...                 ...                   ...
# 5909305             17998610 2017-12-27 09:20:00  Sugar/Flavored Syrup
# 5736299             17432379 2017-12-13 19:52:00  Sugar/Flavored Syrup
# 5901144             18263665 2017-12-27 08:03:00  Sugar/Flavored Syrup
# 5660630             17222218 2017-12-07 12:29:00  Sugar/Flavored Syrup
# 5808147             17658789 2017-12-19 18:59:00  Sugar/Flavored Syrup
#
#            sub_category       format  unit_price  discount  quantity  \
# receipt_id
# ...

# %%
purchase_dt.day.head()  ## Ekstarksi tanggal
# Out:
# receipt_id
# 9622257    22
# 9446359    15
# 9470290    15
# 9643416    24
# 9692093    26
# Name: purchase_time, dtype: int64

# %%
purchase_dt.dayofweek.head()  ##Ekstraksi urutan hari salam seminggu 0 = senin
# Out:
# receipt_id
# 9622257    6
# 9446359    6
# 9470290    6
# 9643416    1
# 9692093    3
# Name: purchase_time, dtype: int64

# %%
purchase_dt.hour.head()   #Ektraksi Jam
# Out:
# receipt_id
# 9622257    21
# 9446359    16
# 9470290    12
# 9643416     8
# 9692093    11
# Name: purchase_time, dtype: int64

# %%
purchase_dt.day_name().head()
# Out:
# receipt_id
# 9622257      Sunday
# 9446359      Sunday
# 9470290      Sunday
# 9643416     Tuesday
# 9692093    Thursday
# Name: purchase_time, dtype: object

# %%
df['day'] = purchase_dt.day_name()

# %%
df
# Out:
#             receipts_item_id       purchase_time              category  \
# receipt_id
# 9622257             32369294 2018-07-22 21:19:00                  Rice
# 9446359             31885876 2018-07-15 16:17:00                  Rice
# 9470290             31930241 2018-07-15 12:12:00                  Rice
# 9643416             32418582 2018-07-24 08:27:00                  Rice
# 9692093             32561236 2018-07-26 11:28:00                  Rice
# ...                      ...                 ...                   ...
# 5909305             17998610 2017-12-27 09:20:00  Sugar/Flavored Syrup
# 5736299             17432379 2017-12-13 19:52:00  Sugar/Flavored Syrup
# 5901144             18263665 2017-12-27 08:03:00  Sugar/Flavored Syrup
# 5660630             17222218 2017-12-07 12:29:00  Sugar/Flavored Syrup
# 5808147             17658789 2017-12-19 18:59:00  Sugar/Flavored Syrup
#
#            sub_category       format  unit_price  discount  quantity  \
# receipt_id
# ...

# %%
purchase_dt.to_period('D').head()
# Out:
# receipt_id
# 9622257    2018-07-22
# 9446359    2018-07-15
# 9470290    2018-07-15
# 9643416    2018-07-24
# 9692093    2018-07-26
# Name: purchase_time, dtype: period[D]

# %%
purchase_dt.to_period('M').head()  ## Perbandingan di bulan yang sama tahun beda
# Out:
# receipt_id
# 9622257    2018-07
# 9446359    2018-07
# 9470290    2018-07
# 9643416    2018-07
# 9692093    2018-07
# Name: purchase_time, dtype: period[M]

# %%
purchase_dt.to_period('W').head()  ## Perbandingan di minggu yang sama tahun beda
# Out:
# receipt_id
# 9622257    2018-07-16/2018-07-22
# 9446359    2018-07-09/2018-07-15
# 9470290    2018-07-09/2018-07-15
# 9643416    2018-07-23/2018-07-29
# 9692093    2018-07-23/2018-07-29
# Name: purchase_time, dtype: period[W-SUN]

# %%
purchase_dt.to_period('Q').sample(5)  ## Perbandingan di kuartal
# Out:
# receipt_id
# 4952294     2017Q4
# 9897945     2018Q3
# 5916664     2017Q4
# 11168141    2018Q3
# 8507565     2018Q2
# Name: purchase_time, dtype: period[Q-DEC]

# %%
df.head()
# Out:
#             receipts_item_id       purchase_time category sub_category  \
# receipt_id
# 9622257             32369294 2018-07-22 21:19:00     Rice         Rice
# 9446359             31885876 2018-07-15 16:17:00     Rice         Rice
# 9470290             31930241 2018-07-15 12:12:00     Rice         Rice
# 9643416             32418582 2018-07-24 08:27:00     Rice         Rice
# 9692093             32561236 2018-07-26 11:28:00     Rice         Rice
#
#                  format  unit_price  discount  quantity month  year       day
# receipt_id
# 9622257     supermarket    128000.0         0         1  July  2018    Sunday
# 9446359      minimarket    102750.0         0         1  July  2018    Sunday
# 9470290     supermarket     64000.0         0         3  July  2018    Sunday
# 9643416      minimarket     65000.0         0         1  July  2018   Tuesday
# 9692093     supermarket    124500.0         0         1  July  2018  Thursday

# %%
df['quarter'] = purchase_dt.to_period('Q')
df.sample(5)
# Out:
#             receipts_item_id       purchase_time              category  \
# receipt_id
# 10513354            35144551 2018-08-26 20:02:00           Fabric Care
# 7481852             22360169 2018-04-02 21:50:00  Sugar/Flavored Syrup
# 8446811             28942875 2018-05-26 00:00:00           Fabric Care
# 6836085             20648985 2018-03-03 17:06:00           Fabric Care
# 11386205            37836985 2018-09-30 10:10:00  Sugar/Flavored Syrup
#
#            sub_category       format  unit_price  discount  quantity  \
# receipt_id
# 10513354      Detergent   minimarket     28900.0         0         1
# 7481852           Sugar   minimarket     12500.0         0         2
# 8446811       Detergent   minimarket     15000.0         0         2
# 6836085       Detergent  supermarket      4230.0         0         1
# 11386205          Sugar   minimarket     12500.0         0         1
#
#                 month  year       day quarter
# receipt_id
# ...

# %%
df['total'] = df['quantity'] * df['unit_price']
df.head()
# Out:
#             receipts_item_id       purchase_time category sub_category  \
# receipt_id
# 9622257             32369294 2018-07-22 21:19:00     Rice         Rice
# 9446359             31885876 2018-07-15 16:17:00     Rice         Rice
# 9470290             31930241 2018-07-15 12:12:00     Rice         Rice
# 9643416             32418582 2018-07-24 08:27:00     Rice         Rice
# 9692093             32561236 2018-07-26 11:28:00     Rice         Rice
#
#                  format  unit_price  discount  quantity month  year       day  \
# receipt_id
# 9622257     supermarket    128000.0         0         1  July  2018    Sunday
# 9446359      minimarket    102750.0         0         1  July  2018    Sunday
# 9470290     supermarket     64000.0         0         3  July  2018    Sunday
# 9643416      minimarket     65000.0         0         1  July  2018   Tuesday
# 9692093     supermarket    124500.0         0         1  July  2018  Thursday
#
#            quarter     total
# receipt_id
# ...

# %%
df['custom'] = purchase_dt.strftime('%B-%H:%M')

# %%
df.head()
# Out:
#             receipts_item_id       purchase_time category sub_category  \
# receipt_id
# 9622257             32369294 2018-07-22 21:19:00     Rice         Rice
# 9446359             31885876 2018-07-15 16:17:00     Rice         Rice
# 9470290             31930241 2018-07-15 12:12:00     Rice         Rice
# 9643416             32418582 2018-07-24 08:27:00     Rice         Rice
# 9692093             32561236 2018-07-26 11:28:00     Rice         Rice
#
#                  format  unit_price  discount  quantity month  year       day  \
# receipt_id
# 9622257     supermarket    128000.0         0         1  July  2018    Sunday
# 9446359      minimarket    102750.0         0         1  July  2018    Sunday
# 9470290     supermarket     64000.0         0         3  July  2018    Sunday
# 9643416      minimarket     65000.0         0         1  July  2018   Tuesday
# 9692093     supermarket    124500.0         0         1  July  2018  Thursday
#
#            quarter     total      custom
# ...

# %% [markdown]
# ## Analisa Data

# %%
#Pandas memiliki 3 fungsi analisa utama

1. Groupby --> Adopt dari SQL
2. Pivot Table --> Adopt Microsoft Excel
3. Crosstab --> Original Pandas

# %% [markdown]
# ### Analisa univariate - 1 kolom

# %%
df['category'].value_counts()
# Out:
# Fabric Care             36000
# Sugar/Flavored Syrup    24000
# Rice                    12000
# Name: category, dtype: int64

# %%
pd.crosstab(df['category'], columns='jumlah')
## Menggunakan fungsio count
# Out:
# col_0                 jumlah
# category
# Fabric Care            36000
# Rice                   12000
# Sugar/Flavored Syrup   24000

# %%
pd.crosstab(df['format'], columns='jumlah')
# Out:
# col_0        jumlah
# format
# hypermarket    5371
# minimarket    46803
# supermarket   19826

# %%
## Penjualan tertinggi ada di minimarket dan terendah di hypermarket
## Sehingga jika akan melakukan promo sebaiknya dilakukan di minimarket

# %%
pd.crosstab(index=df['category'], columns = 'jumlah')
# Out:
# col_0                 jumlah
# category
# Fabric Care            36000
# Rice                   12000
# Sugar/Flavored Syrup   24000

# %%
### Fungsi aggregation
#- Fungsi aggregation default pada crosstab menggunakan COUNT, sehingga bisa dilakukan tanpa data numerik
#- Ketika melakukan analisa Univariate menggunakan crosstab untuk kolom kategorikal, menghasilkan output yang sama dengan fungsi value_counts()
#- Fungsi value_counts() menghasilkan tipe data series, crosstab menghasilkan data frame

# %% [markdown]
# ### Analisa multivariate - multi kolom

# %%
pd.crosstab(index=df['sub_category'], columns=df['format'])
# Out:
# format        hypermarket  minimarket  supermarket
# sub_category
# Detergent            2611       24345         9044
# Rice                  999        7088         3913
# Sugar                1761       15370         6869

# %%
pd.crosstab(index=df['format'], columns=df['sub_category'])
# Out:
# sub_category  Detergent  Rice  Sugar
# format
# hypermarket        2611   999   1761
# minimarket        24345  7088  15370
# supermarket        9044  3913   6869

# %%
pd.crosstab(index=df['sub_category'], columns=df['day'])
# Out:
# day           Friday  Monday  Saturday  Sunday  Thursday  Tuesday  Wednesday
# sub_category
# Detergent       5748    4337      6147    6381      4320     4522       4545
# Rice            1646    1551      1915    2234      1552     1621       1481
# Sugar           3384    3162      3766    3958      3266     3284       3180

# %%
pd.crosstab(index=df['day'], columns=df['sub_category'])
# Out:
# sub_category  Detergent  Rice  Sugar
# day
# Friday             5748  1646   3384
# Monday             4337  1551   3162
# Saturday           6147  1915   3766
# Sunday             6381  2234   3958
# Thursday           4320  1552   3266
# Tuesday            4522  1621   3284
# Wednesday          4545  1481   3180

# %%
pd.crosstab(index=[df['format'], df['sub_category']], columns=df['day'])
# Out:
# day                       Friday  Monday  Saturday  Sunday  Thursday  Tuesday  \
# format      sub_category
# hypermarket Detergent        398     264       538     598       266      291
#             Rice             154     111       175     263       100       94
#             Sugar            250     198       303     374       205      215
# minimarket  Detergent       3884    3003      4000    4097      3027     3108
#             Rice             973     958      1100    1210       902     1011
#             Sugar           2147    2083      2311    2390      2204     2150
# supermarket Detergent       1466    1070      1609    1686      1027     1123
#             Rice             519     482       640     761       550      516
#             Sugar            987     881      1152    1194       857      919
#
# day                       Wednesday
# format      sub_category
# hypermarket Detergent           256
#             Rice                102
# ...

# %%
pd.crosstab(index=df['day'], columns=[df['format'], df['sub_category']])
# Out:
# format       hypermarket            minimarket             supermarket       \
# sub_category   Detergent Rice Sugar  Detergent  Rice Sugar   Detergent Rice
# day
# Friday               398  154   250       3884   973  2147        1466  519
# Monday               264  111   198       3003   958  2083        1070  482
# Saturday             538  175   303       4000  1100  2311        1609  640
# Sunday               598  263   374       4097  1210  2390        1686  761
# Thursday             266  100   205       3027   902  2204        1027  550
# Tuesday              291   94   215       3108  1011  2150        1123  516
# Wednesday            256  102   216       3226   934  2085        1063  445
#
# format
# sub_category Sugar
# day
# Friday         987
# Monday         881
# Saturday      1152
# Sunday        1194
# Thursday       857
# Tuesday        919
# Wednesday      879

# %%
pd.crosstab(index=[df['day'], df['year']], columns=[df['format'], df['sub_category']])
# Out:
# format         hypermarket            minimarket            supermarket       \
# sub_category     Detergent Rice Sugar  Detergent Rice Sugar   Detergent Rice
# day       year
# Friday    2017         109   32    75        955  245   530         336  133
#           2018         289  122   175       2929  728  1617        1130  386
# Monday    2017          59   20    50        733  233   510         266  114
#           2018         205   91   148       2270  725  1573         804  368
# Saturday  2017         128   42    76       1041  280   531         362  187
#           2018         410  133   227       2959  820  1780        1247  453
# Sunday    2017         152   71   100       1098  355   641         436  211
#           2018         446  192   274       2999  855  1749        1250  550
# Thursday  2017          57   19    49        754  225   517         275  127
#           2018         209   81   156       2273  677  1687         752  423
# ...

# %%
pd.crosstab(index=[df['year'], df['day']], columns=[df['format'], df['sub_category']])
# Out:
# format         hypermarket            minimarket            supermarket       \
# sub_category     Detergent Rice Sugar  Detergent Rice Sugar   Detergent Rice
# year day
# 2017 Friday            109   32    75        955  245   530         336  133
#      Monday             59   20    50        733  233   510         266  114
#      Saturday          128   42    76       1041  280   531         362  187
#      Sunday            152   71   100       1098  355   641         436  211
#      Thursday           57   19    49        754  225   517         275  127
#      Tuesday            69   20    54        765  221   545         267  131
#      Wednesday          63   21    49        843  205   522         232  108
# 2018 Friday            289  122   175       2929  728  1617        1130  386
#      Monday            205   91   148       2270  725  1573         804  368
#      Saturday          410  133   227       2959  820  1780        1247  453
# ...

# %%
(pd.crosstab(index=df['format'], columns=df['sub_category'], normalize=True)*100).round(2)
# Out:
# sub_category  Detergent  Rice  Sugar
# format
# hypermarket        3.63  1.39   2.45
# minimarket        33.81  9.84  21.35
# supermarket       12.56  5.43   9.54

# %%
(pd.crosstab(index=df['format'], columns=df['sub_category'], normalize='all')*100).round(2)
# Out:
# sub_category  Detergent  Rice  Sugar
# format
# hypermarket        3.63  1.39   2.45
# minimarket        33.81  9.84  21.35
# supermarket       12.56  5.43   9.54

# %%
#normalize True dan all ==> 100%nya merupakan keseluruhan

# %%
pd.crosstab(index=df['format'], columns=df['sub_category'], normalize='index')*100
# Out:
# sub_category  Detergent       Rice      Sugar
# format
# hypermarket   48.612921  18.599888  32.787190
# minimarket    52.015896  15.144328  32.839775
# supermarket   45.616867  19.736709  34.646424

# %%
pd.crosstab(index=df['format'], columns=df['sub_category'], normalize='columns')*100
# Out:
# sub_category  Detergent       Rice      Sugar
# format
# hypermarket    7.252778   8.325000   7.337500
# minimarket    67.625000  59.066667  64.041667
# supermarket   25.122222  32.608333  28.620833

# %%
pd.crosstab(index=df['format'], columns=df['sub_category'], margins=True)
# Out:
# sub_category  Detergent   Rice  Sugar    All
# format
# hypermarket        2611    999   1761   5371
# minimarket        24345   7088  15370  46803
# supermarket        9044   3913   6869  19826
# All               36000  12000  24000  72000

# %%
pd.crosstab(index=df['format'], columns=df['sub_category'], margins=True, normalize='all')*100
# Out:
# sub_category  Detergent       Rice      Sugar         All
# format
# hypermarket    3.626389   1.387500   2.445833    7.459722
# minimarket    33.812500   9.844444  21.347222   65.004167
# supermarket   12.561111   5.434722   9.540278   27.536111
# All           50.000000  16.666667  33.333333  100.000000

# %%
pd.crosstab(index=df['format'], columns=df['sub_category'], margins=True, normalize='index')*100
# Out:
# sub_category  Detergent       Rice      Sugar
# format
# hypermarket   48.612921  18.599888  32.787190
# minimarket    52.015896  15.144328  32.839775
# supermarket   45.616867  19.736709  34.646424
# All           50.000000  16.666667  33.333333

# %%
pd.crosstab(index=df['format'], columns=df['sub_category'], margins=True, normalize='columns')*100
# Out:
# sub_category  Detergent       Rice      Sugar        All
# format
# hypermarket    7.252778   8.325000   7.337500   7.459722
# minimarket    67.625000  59.066667  64.041667  65.004167
# supermarket   25.122222  32.608333  28.620833  27.536111

# %% [markdown]
# ## Aggregat Function - Data Frame
# - Menggunakan salah satu kolom bertipe data numerik
# - Kolom tersebut akan dikombinasikan dengan kolom kategorik
#
# ## Syarat
# - Parameter values HARUS DIISI ==> Berisi kolom numerik
# - Parameter 'aggfunc' HARUS DIISI ==> Berisi aggfunct yang akan digunakan

# %%
df.head()
# Out:
#             receipts_item_id       purchase_time category sub_category  \
# receipt_id
# 9622257             32369294 2018-07-22 21:19:00     Rice         Rice
# 9446359             31885876 2018-07-15 16:17:00     Rice         Rice
# 9470290             31930241 2018-07-15 12:12:00     Rice         Rice
# 9643416             32418582 2018-07-24 08:27:00     Rice         Rice
# 9692093             32561236 2018-07-26 11:28:00     Rice         Rice
#
#                  format  unit_price  discount  quantity month  year       day  \
# receipt_id
# 9622257     supermarket    128000.0         0         1  July  2018    Sunday
# 9446359      minimarket    102750.0         0         1  July  2018    Sunday
# 9470290     supermarket     64000.0         0         3  July  2018    Sunday
# 9643416      minimarket     65000.0         0         1  July  2018   Tuesday
# 9692093     supermarket    124500.0         0         1  July  2018  Thursday
#
#            quarter     total      custom
# ...

# %%
pd.crosstab(index=df['sub_category'], columns='harga rata-rata', values=df['unit_price'], aggfunc='mean')
# Out:
# col_0         harga rata-rata
# sub_category
# Detergent        17893.793214
# Rice             70013.146313
# Sugar            12645.066024

# %%
pd.crosstab(index=df['format'], columns=df['sub_category'], values=df['unit_price'], aggfunc='max').round(2)
# Out:
# sub_category  Detergent      Rice    Sugar
# format
# hypermarket     59500.0  214000.0  59950.0
# minimarket      59000.0  219400.0  59900.0
# supermarket     59900.0  219000.0  59950.0

# %%
pd.crosstab(index=df['format'], columns=df['sub_category'], values=df['unit_price'], aggfunc='min').round(2)
# Out:
# sub_category  Detergent     Rice   Sugar
# format
# hypermarket      2600.0  10329.0  5000.0
# minimarket       2505.0   9400.0  5000.0
# supermarket      2510.0   9395.0  5000.0

# %%
pd.crosstab(index=df['format'], columns=df['sub_category'], values=df['unit_price'], aggfunc='mean').round(2)
# Out:
# sub_category  Detergent      Rice     Sugar
# format
# hypermarket    19328.14  71205.46  13539.92
# minimarket     17757.14  67135.57  12352.14
# supermarket    17847.56  74921.18  13071.11

# %%
pd.crosstab(index=df['format'], columns=df['sub_category'], values=df['unit_price'], aggfunc=('mean', 'max', 'min')).round(2)
# Out:
#                    max                         mean                      \
# sub_category Detergent      Rice    Sugar Detergent      Rice     Sugar
# format
# hypermarket    59500.0  214000.0  59950.0  19328.14  71205.46  13539.92
# minimarket     59000.0  219400.0  59900.0  17757.14  67135.57  12352.14
# supermarket    59900.0  219000.0  59950.0  17847.56  74921.18  13071.11
#
#                    min
# sub_category Detergent     Rice   Sugar
# format
# hypermarket     2600.0  10329.0  5000.0
# minimarket      2505.0   9400.0  5000.0
# supermarket     2510.0   9395.0  5000.0

# %%
pd.crosstab(index=[df['sub_category'], df['format']], columns=df['day'], values=df['unit_price'], aggfunc=('mean', 'max', 'min')).round(2)
# Out:
#                                max                                          \
# day                         Friday    Monday  Saturday    Sunday  Thursday
# sub_category format
# Detergent    hypermarket   55440.0   57000.0   58470.0   55560.0   54475.0
#              minimarket    56000.0   57000.0   58000.0   57100.0   57500.0
#              supermarket   57200.0   53200.0   56400.0   59600.0   55000.0
# Rice         hypermarket  141200.0  175000.0  195650.0  129000.0  128000.0
#              minimarket   215000.0  219400.0  215000.0  219000.0  215000.0
#              supermarket  218900.0  219000.0  214000.0  218000.0  192000.0
# Sugar        hypermarket   43815.0   59950.0   59500.0   59900.0   49600.0
#              minimarket    47200.0   57000.0   56000.0   58000.0   59900.0
#              supermarket   58500.0   59500.0   59900.0   59900.0   59950.0
#
#                                                   mean                      \
# ...

# %%
pd.crosstab(index=df['day'], columns=[df['sub_category'], df['format']], margins=True)
# Out:
# sub_category   Detergent                               Rice             \
# format       hypermarket minimarket supermarket hypermarket minimarket
# day
# Friday               398       3884        1466         154        973
# Monday               264       3003        1070         111        958
# Saturday             538       4000        1609         175       1100
# Sunday               598       4097        1686         263       1210
# Thursday             266       3027        1027         100        902
# Tuesday              291       3108        1123          94       1011
# Wednesday            256       3226        1063         102        934
# All                 2611      24345        9044         999       7088
#
# sub_category                   Sugar                           All
# format       supermarket hypermarket minimarket supermarket
# day
# Friday               519         250       2147         987  10778
# ...

# %%
pd.crosstab(index=df['day'], columns=[df['sub_category'], df['format']], values=df['unit_price'], aggfunc='mean').round(2)
# Out:
# sub_category   Detergent                               Rice             \
# format       hypermarket minimarket supermarket hypermarket minimarket
# day
# Friday          18891.04   17694.00    17535.59    73596.73   65973.96
# Monday          19138.56   17560.32    18133.63    66298.69   68546.85
# Saturday        19970.34   17747.66    17773.89    72381.89   66611.12
# Sunday          18831.24   17649.69    17939.16    72182.65   66708.62
# Thursday        19879.21   17987.28    17906.23    68319.88   67578.55
# Tuesday         19389.39   17901.03    17944.18    74470.87   68448.32
# Wednesday       19372.11   17809.98    17797.29    68216.51   66220.13
#
# sub_category                   Sugar
# format       supermarket hypermarket minimarket supermarket
# day
# Friday          77468.79    12885.25   12249.18    12982.34
# Monday          73603.42    13358.89   12457.94    13024.60
# Saturday        74740.14    13939.89   12313.93    13001.97
# ...

# %% [markdown]
# #### Pivot Table
# - Dapat memfilter

# %%
pd.pivot_table(data=df,
              index='day',
              columns=['sub_category', 'format'],
              values='unit_price',
              aggfunc='median')
# Out:
# sub_category   Detergent                               Rice             \
# format       hypermarket minimarket supermarket hypermarket minimarket
# day
# Friday           16312.5    16800.0     16190.0     64000.0    62500.0
# Monday           16952.5    16800.0     16890.0     64000.0    63500.0
# Saturday         16972.5    16800.0     16375.0     64000.0    62500.0
# Sunday           16700.0    16800.0     16600.0     64000.0    62500.0
# Thursday         16995.0    16800.0     16200.0     64000.0    63500.0
# Tuesday          16950.0    16800.0     16900.0     64000.0    63500.0
# Wednesday        17450.0    16800.0     16700.0     64000.0    62900.0
#
# sub_category                   Sugar
# format       supermarket hypermarket minimarket supermarket
# day
# Friday           64000.0   12000.000    12500.0     12400.0
# Monday           64000.0   12273.465    12500.0     12400.0
# Saturday         64000.0   12300.000    12500.0     12400.0
# ...

# %%
df.pivot_table(index='day',
              columns=['sub_category', 'format'],
              values='unit_price',
              aggfunc='median')
# Out:
# sub_category   Detergent                               Rice             \
# format       hypermarket minimarket supermarket hypermarket minimarket
# day
# Friday           16312.5    16800.0     16190.0     64000.0    62500.0
# Monday           16952.5    16800.0     16890.0     64000.0    63500.0
# Saturday         16972.5    16800.0     16375.0     64000.0    62500.0
# Sunday           16700.0    16800.0     16600.0     64000.0    62500.0
# Thursday         16995.0    16800.0     16200.0     64000.0    63500.0
# Tuesday          16950.0    16800.0     16900.0     64000.0    63500.0
# Wednesday        17450.0    16800.0     16700.0     64000.0    62900.0
#
# sub_category                   Sugar
# format       supermarket hypermarket minimarket supermarket
# day
# Friday           64000.0   12000.000    12500.0     12400.0
# Monday           64000.0   12273.465    12500.0     12400.0
# Saturday         64000.0   12300.000    12500.0     12400.0
# ...

# %%
df[df['unit_price']>10000].pivot_table(index='day',
              columns=['sub_category', 'format'],
              values='unit_price',
              aggfunc='median')
# Out:
# sub_category   Detergent                               Rice             \
# format       hypermarket minimarket supermarket hypermarket minimarket
# day
# Friday           16900.0    17200.0     17096.0     64000.0    62500.0
# Monday           17500.0    17300.0     17490.0     64000.0    63500.0
# Saturday         17875.0    17500.0     17190.0     64000.0    62500.0
# Sunday           16990.0    17200.0     17290.0     64000.0    62900.0
# Thursday         17400.0    17500.0     17290.0     64000.0    63500.0
# Tuesday          17800.0    17500.0     17600.0     64000.0    63500.0
# Wednesday        18050.0    17400.0     17350.0     64000.0    62900.0
#
# sub_category                   Sugar
# format       supermarket hypermarket minimarket supermarket
# day
# Friday           64000.0     12200.0    12500.0     12400.0
# Monday           64000.0     12300.0    12500.0     12400.0
# Saturday         64000.0     12300.0    12500.0     12400.0
# ...

# %%
## Perbedaan Crosstab dan Pivot
- Pada crosstab tidak dapat memfilter sedangkan pivot dapat
- Pada pivot table, fungsi aggregate DEFAULTNYA adalah MEAN
- Pada crosstab fungsi agg nya adalah COUNT

# %%
pd.crosstab(df['category'], columns='jumlah')
# Out:
# col_0                 jumlah
# category
# Fabric Care            36000
# Rice                   12000
# Sugar/Flavored Syrup   24000

# %%
pd.pivot_table(data=df, index='category')
## Secara otomatis akan mengeluarkan SELURUH KOLOM NUMERUK dan dihitung MEannya
# Out:
#                          discount  quantity  receipts_item_id         total  \
# category
# Fabric Care           1316.550667  1.379444      2.459785e+07  24057.452666
# Rice                   835.305750  1.332917      2.457950e+07  90366.554917
# Sugar/Flavored Syrup   164.106542  1.712958      2.458355e+07  21329.772002
#
#                         unit_price     year
# category
# Fabric Care           17893.793214  2017.75
# Rice                  70013.146313  2017.75
# Sugar/Flavored Syrup  12645.066024  2017.75

# %%
df.head()
# Out:
#             receipts_item_id       purchase_time category sub_category  \
# receipt_id
# 9622257             32369294 2018-07-22 21:19:00     Rice         Rice
# 9446359             31885876 2018-07-15 16:17:00     Rice         Rice
# 9470290             31930241 2018-07-15 12:12:00     Rice         Rice
# 9643416             32418582 2018-07-24 08:27:00     Rice         Rice
# 9692093             32561236 2018-07-26 11:28:00     Rice         Rice
#
#                  format  unit_price  discount  quantity month  year       day  \
# receipt_id
# 9622257     supermarket    128000.0         0         1  July  2018    Sunday
# 9446359      minimarket    102750.0         0         1  July  2018    Sunday
# 9470290     supermarket     64000.0         0         3  July  2018    Sunday
# 9643416      minimarket     65000.0         0         1  July  2018   Tuesday
# 9692093     supermarket    124500.0         0         1  July  2018  Thursday
#
#            quarter     total      custom
# ...

# %%
def diskon(x):
    return 0.15 *x

# %%
df['diskon'] = df['unit_price'].apply(diskon)

# %%
df.head()
# Out:
#             receipts_item_id       purchase_time category sub_category  \
# receipt_id
# 9622257             32369294 2018-07-22 21:19:00     Rice         Rice
# 9446359             31885876 2018-07-15 16:17:00     Rice         Rice
# 9470290             31930241 2018-07-15 12:12:00     Rice         Rice
# 9643416             32418582 2018-07-24 08:27:00     Rice         Rice
# 9692093             32561236 2018-07-26 11:28:00     Rice         Rice
#
#                  format  unit_price  discount  quantity month  year       day  \
# receipt_id
# 9622257     supermarket    128000.0         0         1  July  2018    Sunday
# 9446359      minimarket    102750.0         0         1  July  2018    Sunday
# 9470290     supermarket     64000.0         0         3  July  2018    Sunday
# 9643416      minimarket     65000.0         0         1  July  2018   Tuesday
# 9692093     supermarket    124500.0         0         1  July  2018  Thursday
#
# ...

# %%
## Format Akhir EDA
1. Kesimpulan
2. Saran
# Out:
#   File "<ipython-input-163-eb012c1abdb5>", line 2
#     1. Kesimpulan
#        ^
# SyntaxError: invalid syntax
